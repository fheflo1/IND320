# %% [markdown]
# What you can now do in the notebook log
#
# You can explore:
#
# Does windspeed correlate more with wind production during storms?
#
# Does precipitation correlate with hydro after a lag (snowmelt or runoff)?
#
# Does extreme cold increase consumption but not production?
#
# Does wind direction correlate with wind gusts during extreme events?
#
# Does correlation structure break down during extreme conditions?
#
# These are exactly the "data-driven decisioning signals" the assignment wants you to discover.
